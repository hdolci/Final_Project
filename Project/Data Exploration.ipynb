# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./data/Rune_data.csv')

# %%
df.set_index('timestamp')
df.style.format
# Out:
#                Fire_rune  Water_rune  Air_rune  Earth_rune  Mind_rune  \
# timestamp
# 1619222400000          5           4         5           5          3
# 1619308800000          5           5         5           5          3
# 1619395200000          5           5         5           4          3
# 1619481600000          5           5         5           4          3
# 1619568000000          5           5         5           5          3
# ...                  ...         ...       ...         ...        ...
# 1634342400000          5           5         5           4          2
# 1634428800000          5           5         5           4          3
# 1634515200000          5           5         5           5          3
# 1634601600000          5           5         5           4          3
# 1634688000000          5           5         5           4          2
#
#                Body_rune  Death_rune  Nature_rune  Chaos_rune  Law_rune  \
# timestamp
# ...

# %%
print(df.describe())
# Out:
#           timestamp   Fire_rune  Water_rune    Air_rune  Earth_rune  \
# count  1.800000e+02  180.000000   180.00000  180.000000  180.000000
# mean   1.626955e+12    5.005556     4.90000    4.955556    4.833333
# std    4.501929e+09    0.224161     0.33593    0.255054    0.373718
# min    1.619222e+12    4.000000     4.00000    4.000000    4.000000
# 25%    1.623089e+12    5.000000     5.00000    5.000000    5.000000
# 50%    1.626955e+12    5.000000     5.00000    5.000000    5.000000
# 75%    1.630822e+12    5.000000     5.00000    5.000000    5.000000
# max    1.634688e+12    6.000000     6.00000    6.000000    5.000000
#
#         Mind_rune   Body_rune  Death_rune  Nature_rune  Chaos_rune  \
# count  180.000000  180.000000  180.000000   180.000000  180.000000
# mean     2.716667    5.688889  191.355556   189.705556   46.694444
# std      0.464072    0.627925   12.717218    13.705480    3.644997
# min      1.000000    4.000000  174.000000   164.000000   39.000000
# ...

# %%
print(df.shape)
# Out:
# (180, 14)

# %%
print(df.dtypes)
# Out:
# timestamp      int64
# Fire_rune      int64
# Water_rune     int64
# Air_rune       int64
# Earth_rune     int64
# Mind_rune      int64
# Body_rune      int64
# Death_rune     int64
# Nature_rune    int64
# Chaos_rune     int64
# Law_rune       int64
# Cosmic_rune    int64
# Blood_rune     int64
# Soul_rune      int64
# dtype: object

# %%
# Plot, and add heatmap

# %%
df.hist(bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'timestamp'}>,
#         <AxesSubplot:title={'center':'Fire_rune'}>,
#         <AxesSubplot:title={'center':'Water_rune'}>,
#         <AxesSubplot:title={'center':'Air_rune'}>],
#        [<AxesSubplot:title={'center':'Earth_rune'}>,
#         <AxesSubplot:title={'center':'Mind_rune'}>,
#         <AxesSubplot:title={'center':'Body_rune'}>,
#         <AxesSubplot:title={'center':'Death_rune'}>],
#        [<AxesSubplot:title={'center':'Nature_rune'}>,
#         <AxesSubplot:title={'center':'Chaos_rune'}>,
#         <AxesSubplot:title={'center':'Law_rune'}>,
#         <AxesSubplot:title={'center':'Cosmic_rune'}>],
#        [<AxesSubplot:title={'center':'Blood_rune'}>,
#         <AxesSubplot:title={'center':'Soul_rune'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.boxplot(x=df['Chaos_rune'])
# Out:
# <AxesSubplot:xlabel='Chaos_rune'>

# %%
plt.figure(figsize = (20,10))
c = df.corr()
sns.heatmap(c,annot=True)
c
# Out:
#              timestamp  Fire_rune  Water_rune  Air_rune  Earth_rune  \
# timestamp     1.000000   0.161905    0.116814  0.096685    0.055657
# Fire_rune     0.161905   1.000000    0.229985  0.297483    0.277864
# Water_rune    0.116814   0.229985    1.000000  0.534661    0.489494
# Air_rune      0.096685   0.297483    0.534661  1.000000    0.449342
# Earth_rune    0.055657   0.277864    0.489494  0.449342    1.000000
# Mind_rune    -0.153291   0.176326    0.139758  0.223406    0.177166
# Body_rune     0.383670   0.052038    0.063563  0.052711    0.158710
# Death_rune    0.413507   0.391247    0.143062  0.232250    0.210017
# Nature_rune   0.823583   0.204197    0.043318  0.074545    0.062352
# Chaos_rune    0.715763   0.330283    0.184780  0.207651    0.241285
# Law_rune      0.763408   0.111754    0.063008  0.045537    0.106637
# Cosmic_rune   0.665155   0.059868   -0.014715 -0.017544   -0.003247
# Blood_rune    0.613013   0.055655    0.028708 -0.006544    0.118589
# ...

# %%
# Nature, Chaos and Law runes have the highest correlation to each other. If one prices moves, the others will also be impacted.
